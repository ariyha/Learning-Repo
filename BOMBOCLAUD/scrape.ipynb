# %%
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.9 kB 320.0 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.9 kB 393.8 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 327.7 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 359.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/16.5 MB 1.6 MB/s eta 0:00:11
#    ---------------------------------------- 0.1/16.5 MB 2.2 MB/s eta 0:00:08
#     --------------------------------------- 0.3/16.5 MB 2.4 MB/s eta 0:00:07
#     --------------------------------------- 0.3/16.5 MB 2.0 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/16.5 MB 2.2 MB/s eta 0:00:08
# ...

# %%
from instascrape import *

# %%
prof = Profile('https://www.instagram.com/instagram/')

# %%
prof.scrape(inplace=True)
prof.followers
# Out:
# c:\Users\nithi\College\SELF\BOMBOCLAUD\.venv\Lib\site-packages\instascrape\core\_static_scraper.py:134: MissingCookiesWarning: Request header does not contain cookies! It's recommended you pass at least a valid sessionid otherwise Instagram will likely redirect you to their login page.
#   warnings.warn(
# nan
